# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading the data
data = pd.read_csv('/Users/user/Downloads/git hub/Data_related_jobs_glassdoor.csv',encoding='Windows-1252')
data
# Out:
#                              company  \
# 0                          Microsoft
# 1     UT Southwestern Medical Center
# 2                             Notion
# 3                         Net2Aspire
# 4                     Ntropy Network
# ...                              ...
# 2079                         YouTube
# 2080              Hunter Engineering
# 2081     precision technologies corp
# 2082     Argonne National Laboratory
# 2083            Colossal Biosciences
#
#                                               job title       location  \
# 0                              Data & Applied Scientist    Redmond, WA
# 1           Data Scientist or Bioinformatician (remote)         Remote
# 2                                Data Scientist, Growth   New York, NY
# 3                                    Jr. Data Scientist         Remote
# 4                                        Data Scientist         Remote
# ...                                                 ...            ...
# ...

# %%
##data types and null values 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2084 entries, 0 to 2083
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   company              2084 non-null   object
#  1   job title            2084 non-null   object
#  2   location             2084 non-null   object
#  3   job description      2084 non-null   object
#  4   salary estimate      2084 non-null   int64
#  5   company_size         1917 non-null   object
#  6   company_type         1917 non-null   object
#  7   company_sector       1568 non-null   object
#  8   company_industry     1568 non-null   object
#  9   company_founded      1383 non-null   float64
#  10  company_revenue      1917 non-null   object
#  11  hourly               2084 non-null   int64
#  12  rating               1711 non-null   float64
#  13  python_yn            2084 non-null   int64
#  14  spark_yn             2084 non-null   int64
# ...

# %%
data.describe()
# Out:
#        salary estimate  company_founded       hourly       rating  \
# count      2084.000000      1383.000000  2084.000000  1711.000000
# mean     108768.642994      1964.744035     0.166027     4.061368
# std       34434.634748        63.239520     0.372194     0.486386
# min        3760.000000      1625.000000     0.000000     1.000000
# 25%       88384.500000      1943.000000     0.000000     3.800000
# 50%      107747.000000      1984.000000     0.000000     4.100000
# 75%      126495.000000      2008.000000     0.000000     4.300000
# max      297000.000000      2021.000000     1.000000     5.000000
#
#          python_yn     spark_yn     azure_yn       aws_yn     excel_yn  \
# count  2084.000000  2084.000000  2084.000000  2084.000000  2084.000000
# mean      0.712572     0.117083     0.137716     0.293186     0.367083
# std       0.452671     0.321596     0.344684     0.455332     0.482125
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# ...

# %%
#checking for null values 
null=data.isnull().sum()
null
# Out:
# company                  0
# job title                0
# location                 0
# job description          0
# salary estimate          0
# company_size           167
# company_type           167
# company_sector         516
# company_industry       516
# company_founded        701
# company_revenue        167
# hourly                   0
# rating                 373
# python_yn                0
# spark_yn                 0
# azure_yn                 0
# aws_yn                   0
# excel_yn                 0
# machine_learning_yn      0
# job_simpl                0
# seniority                0
# description_len          0
# company_age            701
# dtype: int64

# %%
# Bar plot showing the distribution of null values
plt.figure(figsize=(10, 6))
null.plot.bar()
plt.title('Distribution of Null Values')
plt.xlabel('Columns')
plt.ylabel('Count')
plt.show()

# %%
#filling all missing values with 9999
data.fillna(999999, inplace=True)

# %%
#checking for null values 
null=data.isnull().sum()
null
# Out:
# company                0
# job title              0
# location               0
# job description        0
# salary estimate        0
# company_size           0
# company_type           0
# company_sector         0
# company_industry       0
# company_founded        0
# company_revenue        0
# hourly                 0
# rating                 0
# python_yn              0
# spark_yn               0
# azure_yn               0
# aws_yn                 0
# excel_yn               0
# machine_learning_yn    0
# job_simpl              0
# seniority              0
# description_len        0
# company_age            0
# dtype: int64

# %%
#which data related field has the most postings

# Getting the value counts and plot
plt.figure(figsize=(12, 8))
counts = data['job_simpl'].value_counts()
bars = counts.plot(kind='bar', color=sns.color_palette("pastel"))

# Adding plot labels
plt.title('Number of Data-Related Job Postings by Field', fontsize=18)
plt.xlabel('Data Fields', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.xticks(rotation=45)

# Adding count labels on top of bars
for i, v in enumerate(counts):
    bars.text(i, v+5, str(v), horizontalalignment='center', fontsize=12, color='black')

plt.tight_layout()
plt.show()

# %%
data.columns
# Out:
# Index(['company', 'job title', 'location', 'job description',
#        'salary estimate', 'company_size', 'company_type', 'company_sector',
#        'company_industry', 'company_founded', 'company_revenue', 'hourly',
#        'rating', 'python_yn', 'spark_yn', 'azure_yn', 'aws_yn', 'excel_yn',
#        'machine_learning_yn', 'job_simpl', 'seniority', 'description_len',
#        'company_age'],
#       dtype='object')

# %%
#what are the skills necessary for each of the data related postings this column had no missing vales so the data distributionis accurate 

#Create a figure with 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(18, 14))

# Data Scientist
filtered_data_scientist = data[data['job_simpl'].str.contains('data scientist', case=False)]
sum_data_scientist = filtered_data_scientist[['python_yn', 'spark_yn', 'azure_yn', 'aws_yn', 'excel_yn', 'machine_learning_yn']].sum()
sum_data_scientist = sum_data_scientist.sort_values(ascending=False)
axs[0, 0].bar(sum_data_scientist.index, sum_data_scientist.values)
axs[0, 0].set_title('Distribution of skills a data scientist should have')
axs[0, 0].set_xlabel('Skills')
axs[0, 0].set_ylabel('Skill count')

# Data Analyst
filtered_data_analyst = data[data['job_simpl'].str.contains('data analyst', case=False)]
sum_data_analyst = filtered_data_analyst[['python_yn', 'spark_yn', 'azure_yn', 'aws_yn', 'excel_yn', 'machine_learning_yn']].sum()
sum_data_analyst = sum_data_analyst.sort_values(ascending=False)
axs[0, 1].bar(sum_data_analyst.index, sum_data_analyst.values)
axs[0, 1].set_title('Distribution of skills a data analyst should have')
axs[0, 1].set_xlabel('Skills')
axs[0, 1].set_ylabel('Skill count')

# Data Engineer
filtered_data_engineer = data[data['job_simpl'].str.contains('data engineer', case=False)]
sum_data_engineer = filtered_data_engineer[['python_yn', 'spark_yn', 'azure_yn', 'aws_yn', 'excel_yn', 'machine_learning_yn']].sum()
sum_data_engineer = sum_data_engineer.sort_values(ascending=False)
axs[1, 0].bar(sum_data_engineer.index, sum_data_engineer.values)
axs[1, 0].set_title('Distribution of skills a data engineer should have')
axs[1, 0].set_xlabel('Skills')
axs[1, 0].set_ylabel('Skill count')

# Machine Learning Engineer
filtered_machine_learning_engineer = data[data['job_simpl'].str.contains('machine learning engineer', case=False)]
sum_machine_learning_engineer = filtered_machine_learning_engineer[['python_yn', 'spark_yn', 'azure_yn', 'aws_yn', 'excel_yn', 'machine_learning_yn']].sum()
sum_machine_learning_engineer = sum_machine_learning_engineer.sort_values(ascending=False)
axs[1, 1].bar(sum_machine_learning_engineer.index, sum_machine_learning_engineer.values)
axs[1, 1].set_title('Distribution of skills a machine learning engineer should have')
axs[1, 1].set_xlabel('Skills')
axs[1, 1].set_ylabel('Skill count')

# Adjust spacing between subplots
fig.tight_layout()

# Display the plot
plt.show()

# %%
# What is the maximum salary for each related field 
#Data scientist
# find the maximum salary for each role 
max_salary_data_scientist= filtered_data_scientist['salary estimate'].max()
max_salary_data_scientist

#Data Analyst
max_salary_data_analyst = filtered_data_analyst['salary estimate'].max()
max_salary_data_analyst

#Data engineer 
max_salary_data_engineer= filtered_data_engineer['salary estimate'].max()
max_salary_data_engineer

#Machine learnig engineer 
max_salary_machine_learning_engineer= filtered_machine_learning_engineer['salary estimate'].max()
max_salary_machine_learning_engineer

max_salaries = [max_salary_data_scientist, max_salary_data_analyst, max_salary_data_engineer, max_machine_learning_engineer]
roles = ['Data Scientist', 'Data Analyst', 'Data Engineer', 'Machine Learning Engineer']

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']

plt.figure(figsize=(10, 10))
max_salaries, roles, colors = zip(*sorted(zip(max_salaries, roles, colors), reverse=True))
plt.bar(roles, max_salaries, color=colors)

plt.title('Maximum Salaries for Data-Related Roles')
plt.xlabel('Role')
plt.ylabel('Salary ($)')
plt.ylim((0, max(max_salaries)+10000))

# Adding count labels on top of bars
for i, v in enumerate(max_salaries):
    plt.text(i, v+500, str(v), ha='center', fontsize=12, color='black')

plt.tight_layout()
plt.show()

# %%
# Job details that pay data analsyt 270000
data_analyst_max_job_details= filtered_data_analyst[filtered_data_analyst['salary estimate'] == 270000]
data_analyst_max_job_details
# Out:
#          company                 job title           location  \
# 1679  Braintrust  Sr. Finance Data Analyst  San Francisco, CA
#
#                                         job description  salary estimate  \
# 1679  JOB TYPE: Freelance, Contract Position (no age...           270000
#
#      company_size       company_type           company_sector  \
# 1679      Unknown  Company - Private  Management & Consulting
#
#          company_industry  company_founded  ... python_yn  spark_yn  azure_yn  \
# 1679  Business Consulting           2018.0  ...         0         0         0
#
#       aws_yn  excel_yn  machine_learning_yn     job_simpl  seniority  \
# 1679       0         1                    0  data analyst     Senior
#
#       description_len company_age
# 1679              597         4.0
#
# [1 rows x 23 columns]

# %%
#In which sector is data related skills needed the most

# %%
#Top ten locations with the most postings for data analyst jobs 
location_counts_data_analyst = filtered_data_analyst['location'].value_counts()
top_10_locations = location_counts_data_analyst.head(10)
print(top_10_locations)
# Out:
# Remote                   78
# Greenwood Village, CO    23
# Conshohocken, PA         21
# Vienna, NY               19
# New York, NY             14
# Chicago, IL              10
# Rome, NY                  6
# Oakland, CA               6
# Philadelphia, PA          6
# Whippany, NJ              5
# Name: location, dtype: int64

# %%
# Create a bar chart of the location data with custom colors
plt.figure(figsize=(8, 8))
top_10_locations.plot(kind='bar', color=['red', 'orange', 'yellow', 'green', 'blue', 'purple', 'pink', 'brown', 'gray', 'black'])

plt.title('Top 10 Locations')
plt.xlabel('Location')
plt.ylabel('Count')

plt.show()
